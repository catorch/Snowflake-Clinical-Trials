# %%
# !pip install snowflake-connector-python
# !pip install snowflake-connector-python[pandas]

# %%
import pandas as pd

df = pd.read_csv("data/ClinicalTrialsData.csv",index_col="Unnamed: 0")
df.head()
# Out:
#          nctid  target_label  number_collaborators  number_officials  \
# 0  NCT01923116             0                     2                 2
# 1  NCT01763021             0                     0                 1
# 2  NCT01179308             1                     0                 1
# 3  NCT00427778             1                     1                 1
# 4  NCT00376467             0                     0                 1
#
#    num_arms  number_countries  number_sites  no_elig_req  inclusion_lines  \
# 0       1.0                 1             1            0                6
# 1       1.0                 1             1            0                2
# 2       2.0                 2             2            0                3
# 3       2.0                 1             1            0                3
# 4       0.0                 1            28            0                3
#
#    exclusion_lines  ...        90        91        92        93        94  \
# 0                6  ...  3.039853 -3.300040  1.487360  1.478261  2.550636
# 1                4  ...  0.513191 -1.393093  0.940864  0.088683  0.074904
# 2                4  ...  2.163420 -0.411902 -0.035816  3.557102 -2.521656
# 3                3  ...  3.769808 -1.176595  0.247578  1.944952 -0.830502
# 4                9  ... -2.228156 -4.341137  1.126694  2.487203  1.253972
#
#          95        96        97        98        99
# 0  1.517649  1.237359  3.249761  1.415775  1.477161
# 1 -1.793713  0.749069  1.982955 -1.104483  1.344036
# 2 -3.917873  0.496561  1.281240 -0.059275 -0.031860
# 3  0.593395 -2.722616  0.866244  2.003813  1.861063
# 4 -0.105168  3.125254  3.700899  1.906987  3.855995
#
# [5 rows x 642 columns]

# %%
data_types = df.dtypes
data_types
# Out:
# Unnamed: 0                int64
# nctid                    object
# target_label              int64
# number_collaborators      int64
# number_officials          int64
#                          ...
# 95                      float64
# 96                      float64
# 97                      float64
# 98                      float64
# 99                      float64
# Length: 643, dtype: object

# %%
# Get data types of the columns in the dataframe
data_types = df.dtypes

# Initialize an empty list to hold column definitions
column_definitions = []

# Mapping from pandas data types to Snowflake data types
type_mapping = {
    'int64': 'INTEGER',
    'float64': 'FLOAT',
    'object': 'TEXT',     
}

# Generate the column definitions for the Snowflake table
for column_name, data_type in data_types.items():
    snowflake_type = type_mapping.get(str(data_type), 'TEXT')
    column_definitions.append(f'"{column_name}" {snowflake_type}')

# %%
column_definitions
# Out:
# ['"nctid" TEXT',
#  '"target_label" INTEGER',
#  '"number_collaborators" INTEGER',
#  '"number_officials" INTEGER',
#  '"num_arms" FLOAT',
#  '"number_countries" INTEGER',
#  '"number_sites" INTEGER',
#  '"no_elig_req" INTEGER',
#  '"inclusion_lines" INTEGER',
#  '"exclusion_lines" INTEGER',
#  '"eligibility_lines" INTEGER',
#  '"inclusion_words" INTEGER',
#  '"exclusion_words" INTEGER',
#  '"eligibility_words" INTEGER',
#  '"inclusion_numbers" INTEGER',
#  '"exclusion_numbers" INTEGER',
#  '"eligibility_numbers" INTEGER',
#  '"avg_ex_line_words" FLOAT',
#  '"avg_in_line_words" FLOAT',
#  '"avg_elig_words" FLOAT',
#  '"has_expanded_access" INTEGER',
#  '"industry_sponsor" INTEGER',
#  '"industry_collaborator" INTEGER',
#  '"has_dmc" INTEGER',
#  '"fda_reg" INTEGER',
#  '"has_oversight" INTEGER',
#  '"gender_restriction" INTEGER',
#  '"random_groups" INTEGER',
#  '"no_phase" INTEGER',
#  '"phase_1" INTEGER',
#  '"phase_2" INTEGER',
#  '"phase_3" INTEGER',
#  '"phase_4" INTEGER',
#  '"responsible_party_category_none" INTEGER',
#  '"responsible_party_category_investigator" INTEGER',
#  '"responsible_party_category_sponsor" INTEGER',
#  '"interventional_study" INTEGER',
#  '"uses_blinding" INTEGER',
#  '"age_restriction" INTEGER',
#  '"healthy_volunteer" INTEGER',
#  '"usa" INTEGER',
#  '"placebo_group" INTEGER',
#  '"abdominal" FLOAT',
#  '"ablation" FLOAT',
#  '"abnormalities" FLOAT',
#  '"abuse" FLOAT',
#  '"acid" FLOAT',
#  '"acids" FLOAT',
#  '"activity" FLOAT',
#  '"acute" FLOAT',
#  '"adenocarcinoma" FLOAT',
#  '"adherence" FLOAT',
#  '"adolescent" FLOAT',
#  '"adolescents" FLOAT',
#  '"adult" FLOAT',
#  '"adults" FLOAT',
#  '"advanced" FLOAT',
#  '"age" FLOAT',
#  '"agents" FLOAT',
#  '"aging" FLOAT',
#  '"aids" FLOAT',
#  '"airway" FLOAT',
#  '"alcohol" FLOAT',
#  '"allergy" FLOAT',
#  '"alpha" FLOAT',
#  '"alzheimer" FLOAT',
#  '"aml" FLOAT',
#  '"analgesia" FLOAT',
#  '"analysis" FLOAT',
#  '"anaplastic" FLOAT',
#  '"anemia" FLOAT',
#  '"anesthesia" FLOAT',
#  '"anti" FLOAT',
#  '"antibody" FLOAT',
#  '"anxiety" FLOAT',
#  '"aortic" FLOAT',
#  '"apnea" FLOAT',
#  '"arterial" FLOAT',
#  '"artery" FLOAT',
#  '"arthritis" FLOAT',
#  '"arthroplasty" FLOAT',
#  '"assessment" FLOAT',
#  '"assisted" FLOAT',
#  '"associated" FLOAT',
#  '"asthma" FLOAT',
#  '"astrocytoma" FLOAT',
#  '"atrial" FLOAT',
#  '"attention" FLOAT',
#  '"autism" FLOAT',
#  '"b" FLOAT',
#  '"back" FLOAT',
#  '"balance" FLOAT',
#  '"based" FLOAT',
#  '"behavior" FLOAT',
#  '"behavioral" FLOAT',
#  '"beta" FLOAT',
#  '"bevacizumab" FLOAT',
#  '"bioequivalence" FLOAT',
#  '"biomarkers" FLOAT',
#  '"biopsy" FLOAT',
#  '"bipolar" FLOAT',
#  '"bladder" FLOAT',
#  '"bleeding" FLOAT',
#  '"block" FLOAT',
#  '"blood" FLOAT',
#  '"body" FLOAT',
#  '"bone" FLOAT',
#  '"bowel" FLOAT',
#  '"brain" FLOAT',
#  '"breast" FLOAT',
#  '"burkitt" FLOAT',
#  '"bypass" FLOAT',
#  '"c" FLOAT',
#  '"cancer" FLOAT',
#  '"carcinoma" FLOAT',
#  '"cardiac" FLOAT',
#  '"cardiovascular" FLOAT',
#  '"care" FLOAT',
#  '"catheter" FLOAT',
#  '"cavity" FLOAT',
#  '"cell" FLOAT',
#  '"cells" FLOAT',
#  '"central" FLOAT',
#  '"cerebral" FLOAT',
#  '"cervical" FLOAT',
#  '"cessation" FLOAT',
#  '"chemotherapy" FLOAT',
#  '"child" FLOAT',
#  '"childhood" FLOAT',
#  '"children" FLOAT',
#  '"cholesterol" FLOAT',
#  '"chronic" FLOAT',
#  '"cleaved" FLOAT',
#  '"clinical" FLOAT',
#  '"cognition" FLOAT',
#  '"cognitive" FLOAT',
#  '"colon" FLOAT',
#  '"colonoscopy" FLOAT',
#  '"colorectal" FLOAT',
#  '"community" FLOAT',
#  '"complications" FLOAT',
#  '"contiguous" FLOAT',
#  '"continuous" FLOAT',
#  '"control" FLOAT',
#  '"controlled" FLOAT',
#  '"copd" FLOAT',
#  '"cord" FLOAT',
#  '"coronary" FLOAT',
#  '"critical" FLOAT',
#  '"ct" FLOAT',
#  '"cutaneous" FLOAT',
#  '"cystic" FLOAT',
#  '"decision" FLOAT',
#  '"deficiency" FLOAT',
#  '"degeneration" FLOAT',
#  '"delivery" FLOAT',
#  '"dementia" FLOAT',
#  '"density" FLOAT',
#  '"dental" FLOAT',
#  '"dependence" FLOAT',
#  '"depression" FLOAT',
#  '"depressive" FLOAT',
#  '"device" FLOAT',
#  '"diabetes" FLOAT',
#  '"diabetic" FLOAT',
#  '"diagnosis" FLOAT',
#  '"dialysis" FLOAT',
#  '"diet" FLOAT',
#  '"dietary" FLOAT',
#  '"diffuse" FLOAT',
#  '"disease" FLOAT',
#  '"diseases" FLOAT',
#  '"disorder" FLOAT',
#  '"disorders" FLOAT',
#  '"dose" FLOAT',
#  '"double" FLOAT',
#  '"drug" FLOAT',
#  '"dysfunction" FLOAT',
#  '"early" FLOAT',
#  '"edema" FLOAT',
#  '"education" FLOAT',
#  '"effect" FLOAT',
#  '"effectiveness" FLOAT',
#  '"effects" FLOAT',
#  '"efficacy" FLOAT',
#  '"elderly" FLOAT',
#  '"emergency" FLOAT',
#  '"end" FLOAT',
#  '"endometrial" FLOAT',
#  '"endothelial" FLOAT',
#  '"energy" FLOAT',
#  '"epilepsy" FLOAT',
#  '"epithelial" FLOAT',
#  '"esophageal" FLOAT',
#  '"esophagus" FLOAT',
#  '"exercise" FLOAT',
#  '"experienced" FLOAT',
#  '"exposure" FLOAT',
#  '"extranodal" FLOAT',
#  '"eye" FLOAT',
#  '"factor" FLOAT',
#  '"factors" FLOAT',
#  '"failure" FLOAT',
#  '"family" FLOAT',
#  '"fat" FLOAT',
#  '"fatigue" FLOAT',
#  '"fatty" FLOAT',
#  '"fibrillation" FLOAT',
#  '"fibrosis" FLOAT',
#  '"first" FLOAT',
#  '"flow" FLOAT',
#  '"fluid" FLOAT',
#  '"fmri" FLOAT',
#  '"follicular" FLOAT',
#  '"food" FLOAT',
#  '"fracture" FLOAT',
#  '"function" FLOAT',
#  '"functional" FLOAT',
#  '"fungoides" FLOAT',
#  '"gait" FLOAT',
#  '"gastric" FLOAT',
#  '"gastrointestinal" FLOAT',
#  '"gene" FLOAT',
#  '"genetic" FLOAT',
#  '"germ" FLOAT',
#  '"gland" FLOAT',
#  '"glaucoma" FLOAT',
#  '"glioblastoma" FLOAT',
#  '"glioma" FLOAT',
#  '"glucose" FLOAT',
#  '"grade" FLOAT',
#  '"graft" FLOAT',
#  '"group" FLOAT',
#  '"growth" FLOAT',
#  '"head" FLOAT',
#  '"health" FLOAT',
#  '"healthy" FLOAT',
#  '"heart" FLOAT',
#  '"hemodialysis" FLOAT',
#  '"hemorrhage" FLOAT',
#  '"hepatitis" FLOAT',
#  '"hepatocellular" FLOAT',
#  '"high" FLOAT',
#  '"hip" FLOAT',
#  '"hiv" FLOAT',
#  '"hodgkin" FLOAT',
#  '"home" FLOAT',
#  '"hormone" FLOAT',
#  '"human" FLOAT',
#  '"hv" FLOAT',
#  '"hypertension" FLOAT',
#  '"hypopharynx" FLOAT',
#  '"idiopathic" FLOAT',
#  '"ii" FLOAT',
#  '"iii" FLOAT',
#  '"iiia" FLOAT',
#  '"iiib" FLOAT',
#  '"iiic" FLOAT',
#  '"illness" FLOAT',
#  '"imaging" FLOAT',
#  '"immune" FLOAT',
#  '"immunoblastic" FLOAT',
#  '"immunotherapy" FLOAT',
#  '"impairment" FLOAT',
#  '"incontinence" FLOAT',
#  '"index" FLOAT',
#  '"induced" FLOAT',
#  '"infant" FLOAT',
#  '"infants" FLOAT',
#  '"infarction" FLOAT',
#  '"infection" FLOAT',
#  '"infections" FLOAT',
#  '"inflammation" FLOAT',
#  '"inflammatory" FLOAT',
#  '"influenza" FLOAT',
#  '"infusion" FLOAT',
#  '"inhibitor" FLOAT',
#  '"inhibitors" FLOAT',
#  '"injection" FLOAT',
#  '"injury" FLOAT',
#  '"insulin" FLOAT',
#  '"intensive" FLOAT',
#  '"intervention" FLOAT',
#  '"intravenous" FLOAT',
#  '"intubation" FLOAT',
#  '"invasive" FLOAT',
#  '"iron" FLOAT',
#  '"ischemia" FLOAT',
#  '"ischemic" FLOAT',
#  '"iv" FLOAT',
#  '"joint" FLOAT',
#  '"kidney" FLOAT',
#  '"knee" FLOAT',
#  '"large" FLOAT',
#  '"larynx" FLOAT',
#  '"laser" FLOAT',
#  '"left" FLOAT',
#  '"leukemia" FLOAT',
#  '"life" FLOAT',
#  '"lip" FLOAT',
#  '"liver" FLOAT',
#  '"long" FLOAT',
#  '"loss" FLOAT',
#  '"low" FLOAT',
#  '"lung" FLOAT',
#  '"lymphoblastic" FLOAT',
#  '"lymphocytic" FLOAT',
#  '"lymphoid" FLOAT',
#  '"lymphoma" FLOAT',
#  '"macular" FLOAT',
#  '"magnetic" FLOAT',
#  '"major" FLOAT',
#  '"male" FLOAT',
#  '"malignant" FLOAT',
#  '"management" FLOAT',
#  '"mantle" FLOAT',
#  '"marginal" FLOAT',
#  '"markers" FLOAT',
#  '"marrow" FLOAT',
#  '"mass" FLOAT',
#  '"mechanical" FLOAT',
#  '"medical" FLOAT',
#  '"medication" FLOAT',
#  '"medicine" FLOAT',
#  '"melanoma" FLOAT',
#  '"mellitus" FLOAT',
#  '"memory" FLOAT',
#  '"mental" FLOAT',
#  '"metabolic" FLOAT',
#  '"metabolism" FLOAT',
#  '"metastases" FLOAT',
#  '"metastatic" FLOAT',
#  '"migraine" FLOAT',
#  '"mild" FLOAT',
#  '"mixed" FLOAT',
#  '"monitoring" FLOAT',
#  '"monoclonal" FLOAT',
#  '"motor" FLOAT',
#  '"mri" FLOAT',
#  '"multiple" FLOAT',
#  '"muscle" FLOAT',
#  '"mycosis" FLOAT',
#  '"myelodysplastic" FLOAT',
#  '"myelogenous" FLOAT',
#  '"myeloid" FLOAT',
#  '"myeloma" FLOAT',
#  '"myelomonocytic" FLOAT',
#  '"myocardial" FLOAT',
#  '"nasal" FLOAT',
#  '"nasopharynx" FLOAT',
#  '"neck" FLOAT',
#  '"negative" FLOAT',
#  '"neoplasm" FLOAT',
#  '"neoplasms" FLOAT',
#  '"nerve" FLOAT',
#  '"nervous" FLOAT',
#  '"neuroblastoma" FLOAT',
#  '"neuropathy" FLOAT',
#  '"nicotine" FLOAT',
#  '"non" FLOAT',
#  '"noncontiguous" FLOAT',
#  '"normal" FLOAT',
#  '"nsclc" FLOAT',
#  '"nutrition" FLOAT',
#  '"obesity" FLOAT',
#  '"obstructive" FLOAT',
#  '"open" FLOAT',
#  '"operative" FLOAT',
#  '"opioid" FLOAT',
#  '"oral" FLOAT',
#  '"oropharynx" FLOAT',
#  '"osteoarthritis" FLOAT',
#  '"osteoporosis" FLOAT',
#  '"outcome" FLOAT',
#  '"outcomes" FLOAT',
#  '"ovarian" FLOAT',
#  '"overweight" FLOAT',
#  '"oxidative" FLOAT',
#  '"oxygen" FLOAT',
#  '"pain" FLOAT',
#  '"pancreas" FLOAT',
#  '"pancreatic" FLOAT',
#  '"paranasal" FLOAT',
#  '"parkinson" FLOAT',
#  '"patient" FLOAT',
#  '"patients" FLOAT',
#  '"pediatric" FLOAT',
#  '"pediatrics" FLOAT',
#  '"pelvic" FLOAT',
#  '"percutaneous" FLOAT',
#  '"performance" FLOAT',
#  '"peripheral" FLOAT',
#  '"peritoneal" FLOAT',
#  '"pet" FLOAT',
#  '"pharmacokinetics" FLOAT',
#  '"phase_keyword" FLOAT',
#  '"physical" FLOAT',
#  '"placebo" FLOAT',
#  '"plasma" FLOAT',
#  '"platelet" FLOAT',
#  '"positive" FLOAT',
#  '"post" FLOAT',
#  '"postoperative" FLOAT',
#  '"pregnancy" FLOAT',
#  '"pressure" FLOAT',
#  '"preterm" FLOAT',
#  '"prevention" FLOAT',
#  '"previously" FLOAT',
#  '"primary" FLOAT',
#  '"prophylaxis" FLOAT',
#  '"prostate" FLOAT',
#  '"protein" FLOAT',
#  '"protocol" FLOAT',
#  '"psoriasis" FLOAT',
#  '"ptsd" FLOAT',
#  '"pulmonary" FLOAT',
#  '"quality" FLOAT',
#  '"radiation" FLOAT',
#  '"radiotherapy" FLOAT',
#  '"randomized" FLOAT',
#  '"rate" FLOAT',
#  '"receptor" FLOAT',
#  '"recovery" FLOAT',
#  '"rectal" FLOAT',
#  '"recurrent" FLOAT',
#  '"reduction" FLOAT',
#  '"refractory" FLOAT',
#  '"rehabilitation" FLOAT',
#  '"relapsed" FLOAT',
#  '"related" FLOAT',
#  '"remission" FLOAT',
#  '"renal" FLOAT',
#  '"replacement" FLOAT',
#  '"research" FLOAT',
#  '"resistance" FLOAT',
#  '"resistant" FLOAT',
#  '"resonance" FLOAT',
#  '"respiratory" FLOAT',
#  '"response" FLOAT',
#  '"rheumatoid" FLOAT',
#  '"risk" FLOAT',
#  '"safety" FLOAT',
#  '"salivary" FLOAT',
#  '"sarcoma" FLOAT',
#  '"schizophrenia" FLOAT',
#  '"sclerosis" FLOAT',
#  '"screening" FLOAT',
#  '"secondary" FLOAT',
#  '"sedation" FLOAT',
#  '"self" FLOAT',
#  '"sensitivity" FLOAT',
#  '"sepsis" FLOAT',
#  '"severe" FLOAT',
#  '"sexual" FLOAT',
#  '"sezary" FLOAT',
#  '"single" FLOAT',
#  '"sinus" FLOAT',
#  '"skin" FLOAT',
#  '"sleep" FLOAT',
#  '"small" FLOAT',
#  '"smoking" FLOAT',
#  '"social" FLOAT',
#  '"sodium" FLOAT',
#  '"soft" FLOAT',
#  '"solid" FLOAT',
#  '"specific" FLOAT',
#  '"spinal" FLOAT',
#  '"squamous" FLOAT',
#  '"stage" FLOAT',
#  '"status_keyword" FLOAT',
#  '"stem" FLOAT',
#  '"stenosis" FLOAT',
#  '"stent" FLOAT',
#  '"stimulation" FLOAT',
#  '"strength" FLOAT',
#  '"stress" FLOAT',
#  '"stroke" FLOAT',
#  '"study" FLOAT',
#  '"subjects" FLOAT',
#  '"substance" FLOAT',
#  '"support" FLOAT',
#  '"surgery" FLOAT',
#  '"surgical" FLOAT',
#  '"symptoms" FLOAT',
#  '"syndrome" FLOAT',
#  '"syndromes" FLOAT',
#  '"system" FLOAT',
#  '"systemic" FLOAT',
#  '"term" FLOAT',
#  '"test" FLOAT',
#  '"testicular" FLOAT',
#  '"testing" FLOAT',
#  '"therapeutic" FLOAT',
#  '"therapy" FLOAT',
#  '"thrombosis" FLOAT',
#  '"thyroid" FLOAT',
#  '"time" FLOAT',
#  '"tissue" FLOAT',
#  '"tobacco" FLOAT',
#  '"tolerability" FLOAT',
#  '"tolerance" FLOAT',
#  '"tomography" FLOAT',
#  '"total" FLOAT',
#  '"tract" FLOAT',
#  '"training" FLOAT',
#  '"transcranial" FLOAT',
#  '"transplant" FLOAT',
#  '"transplantation" FLOAT',
#  '"trauma" FLOAT',
#  '"traumatic" FLOAT',
#  '"treated" FLOAT',
#  '"treatment" FLOAT',
#  '"trial" FLOAT',
#  '"tube" FLOAT',
#  '"tumor" FLOAT',
#  '"tumors" FLOAT',
#  '"type" FLOAT',
#  '"ulcer" FLOAT',
#  '"ultrasound" FLOAT',
#  '"unresectable" FLOAT',
#  '"unspecified" FLOAT',
#  '"untreated" FLOAT',
#  '"urinary" FLOAT',
#  '"use" FLOAT',
#  '"uterine" FLOAT',
#  '"vaccine" FLOAT',
#  '"valve" FLOAT',
#  '"vascular" FLOAT',
#  '"venous" FLOAT',
#  '"ventilation" FLOAT',
#  '"ventricular" FLOAT',
#  '"verrucous" FLOAT',
#  '"virus" FLOAT',
#  '"visual" FLOAT',
#  '"vitamin" FLOAT',
#  '"volume" FLOAT',
#  '"volunteer" FLOAT',
#  '"volunteers" FLOAT',
#  '"weight" FLOAT',
#  '"women" FLOAT',
#  '"wound" FLOAT',
#  '"zone" FLOAT',
#  '"0" FLOAT',
#  '"1" FLOAT',
#  '"2" FLOAT',
#  '"3" FLOAT',
#  '"4" FLOAT',
#  '"5" FLOAT',
#  '"6" FLOAT',
#  '"7" FLOAT',
#  '"8" FLOAT',
#  '"9" FLOAT',
#  '"10" FLOAT',
#  '"11" FLOAT',
#  '"12" FLOAT',
#  '"13" FLOAT',
#  '"14" FLOAT',
#  '"15" FLOAT',
#  '"16" FLOAT',
#  '"17" FLOAT',
#  '"18" FLOAT',
#  '"19" FLOAT',
#  '"20" FLOAT',
#  '"21" FLOAT',
#  '"22" FLOAT',
#  '"23" FLOAT',
#  '"24" FLOAT',
#  '"25" FLOAT',
#  '"26" FLOAT',
#  '"27" FLOAT',
#  '"28" FLOAT',
#  '"29" FLOAT',
#  '"30" FLOAT',
#  '"31" FLOAT',
#  '"32" FLOAT',
#  '"33" FLOAT',
#  '"34" FLOAT',
#  '"35" FLOAT',
#  '"36" FLOAT',
#  '"37" FLOAT',
#  '"38" FLOAT',
#  '"39" FLOAT',
#  '"40" FLOAT',
#  '"41" FLOAT',
#  '"42" FLOAT',
#  '"43" FLOAT',
#  '"44" FLOAT',
#  '"45" FLOAT',
#  '"46" FLOAT',
#  '"47" FLOAT',
#  '"48" FLOAT',
#  '"49" FLOAT',
#  '"50" FLOAT',
#  '"51" FLOAT',
#  '"52" FLOAT',
#  '"53" FLOAT',
#  '"54" FLOAT',
#  '"55" FLOAT',
#  '"56" FLOAT',
#  '"57" FLOAT',
#  '"58" FLOAT',
#  '"59" FLOAT',
#  '"60" FLOAT',
#  '"61" FLOAT',
#  '"62" FLOAT',
#  '"63" FLOAT',
#  '"64" FLOAT',
#  '"65" FLOAT',
#  '"66" FLOAT',
#  '"67" FLOAT',
#  '"68" FLOAT',
#  '"69" FLOAT',
#  '"70" FLOAT',
#  '"71" FLOAT',
#  '"72" FLOAT',
#  '"73" FLOAT',
#  '"74" FLOAT',
#  '"75" FLOAT',
#  '"76" FLOAT',
#  '"77" FLOAT',
#  '"78" FLOAT',
#  '"79" FLOAT',
#  '"80" FLOAT',
#  '"81" FLOAT',
#  '"82" FLOAT',
#  '"83" FLOAT',
#  '"84" FLOAT',
#  '"85" FLOAT',
#  '"86" FLOAT',
#  '"87" FLOAT',
#  '"88" FLOAT',
#  '"89" FLOAT',
#  '"90" FLOAT',
#  '"91" FLOAT',
#  '"92" FLOAT',
#  '"93" FLOAT',
#  '"94" FLOAT',
#  '"95" FLOAT',
#  '"96" FLOAT',
#  '"97" FLOAT',
#  '"98" FLOAT',
#  '"99" FLOAT']

# %%
# Join all column definitions in a single string separated by commas
column_definitions_str = ",\n    ".join(column_definitions)
column_definitions_str
# Out:
# '"nctid" TEXT,\n    "target_label" INTEGER,\n    "number_collaborators" INTEGER,\n    "number_officials" INTEGER,\n    "num_arms" FLOAT,\n    "number_countries" INTEGER,\n    "number_sites" INTEGER,\n    "no_elig_req" INTEGER,\n    "inclusion_lines" INTEGER,\n    "exclusion_lines" INTEGER,\n    "eligibility_lines" INTEGER,\n    "inclusion_words" INTEGER,\n    "exclusion_words" INTEGER,\n    "eligibility_words" INTEGER,\n    "inclusion_numbers" INTEGER,\n    "exclusion_numbers" INTEGER,\n    "eligibility_numbers" INTEGER,\n    "avg_ex_line_words" FLOAT,\n    "avg_in_line_words" FLOAT,\n    "avg_elig_words" FLOAT,\n    "has_expanded_access" INTEGER,\n    "industry_sponsor" INTEGER,\n    "industry_collaborator" INTEGER,\n    "has_dmc" INTEGER,\n    "fda_reg" INTEGER,\n    "has_oversight" INTEGER,\n    "gender_restriction" INTEGER,\n    "random_groups" INTEGER,\n    "no_phase" INTEGER,\n    "phase_1" INTEGER,\n    "phase_2" INTEGER,\n    "phase_3" INTEGER,\n    "phase_4" INTEGER,\n    "responsible_party_category_none" INTEGER,\n    "responsible_party_category_investigator" INTEGER,\n    "responsible_party_category_sponsor" INTEGER,\n    "interventional_study" INTEGER,\n    "uses_blinding" INTEGER,\n    "age_restriction" INTEGER,\n    "healthy_volunteer" INTEGER,\n    "usa" INTEGER,\n    "placebo_group" INTEGER,\n    "abdominal" FLOAT,\n    "ablation" FLOAT,\n    "abnormalities" FLOAT,\n    "abuse" FLOAT,\n    "acid" FLOAT,\n    "acids" FLOAT,\n    "activity" FLOAT,\n    "acute" FLOAT,\n    "adenocarcinoma" FLOAT,\n    "adherence" FLOAT,\n    "adolescent" FLOAT,\n    "adolescents" FLOAT,\n    "adult" FLOAT,\n    "adults" FLOAT,\n    "advanced" FLOAT,\n    "age" FLOAT,\n    "agents" FLOAT,\n    "aging" FLOAT,\n    "aids" FLOAT,\n    "airway" FLOAT,\n    "alcohol" FLOAT,\n    "allergy" FLOAT,\n    "alpha" FLOAT,\n    "alzheimer" FLOAT,\n    "aml" FLOAT,\n    "analgesia" FLOAT,\n    "analysis" FLOAT,\n    "anaplastic" FLOAT,\n    "anemia" FLOAT,\n    "anesthesia" FLOAT,\n    "anti" FLOAT,\n    "antibody" FLOAT,\n    "anxiety" FLOAT,\n    "aortic" FLOAT,\n    "apnea" FLOAT,\n    "arterial" FLOAT,\n    "artery" FLOAT,\n    "arthritis" FLOAT,\n    "arthroplasty" FLOAT,\n    "assessment" FLOAT,\n    "assisted" FLOAT,\n    "associated" FLOAT,\n    "asthma" FLOAT,\n    "astrocytoma" FLOAT,\n    "atrial" FLOAT,\n    "attention" FLOAT,\n    "autism" FLOAT,\n    "b" FLOAT,\n    "back" FLOAT,\n    "balance" FLOAT,\n    "based" FLOAT,\n    "behavior" FLOAT,\n    "behavioral" FLOAT,\n    "beta" FLOAT,\n    "bevacizumab" FLOAT,\n    "bioequivalence" FLOAT,\n    "biomarkers" FLOAT,\n    "biopsy" FLOAT,\n    "bipolar" FLOAT,\n    "bladder" FLOAT,\n    "bleeding" FLOAT,\n    "block" FLOAT,\n    "blood" FLOAT,\n    "body" FLOAT,\n    "bone" FLOAT,\n    "bowel" FLOAT,\n    "brain" FLOAT,\n    "breast" FLOAT,\n    "burkitt" FLOAT,\n    "bypass" FLOAT,\n    "c" FLOAT,\n    "cancer" FLOAT,\n    "carcinoma" FLOAT,\n    "cardiac" FLOAT,\n    "cardiovascular" FLOAT,\n    "care" FLOAT,\n    "catheter" FLOAT,\n    "cavity" FLOAT,\n    "cell" FLOAT,\n    "cells" FLOAT,\n    "central" FLOAT,\n    "cerebral" FLOAT,\n    "cervical" FLOAT,\n    "cessation" FLOAT,\n    "chemotherapy" FLOAT,\n    "child" FLOAT,\n    "childhood" FLOAT,\n    "children" FLOAT,\n    "cholesterol" FLOAT,\n    "chronic" FLOAT,\n    "cleaved" FLOAT,\n    "clinical" FLOAT,\n    "cognition" FLOAT,\n    "cognitive" FLOAT,\n    "colon" FLOAT,\n    "colonoscopy" FLOAT,\n    "colorectal" FLOAT,\n    "community" FLOAT,\n    "complications" FLOAT,\n    "contiguous" FLOAT,\n    "continuous" FLOAT,\n    "control" FLOAT,\n    "controlled" FLOAT,\n    "copd" FLOAT,\n    "cord" FLOAT,\n    "coronary" FLOAT,\n    "critical" FLOAT,\n    "ct" FLOAT,\n    "cutaneous" FLOAT,\n    "cystic" FLOAT,\n    "decision" FLOAT,\n    "deficiency" FLOAT,\n    "degeneration" FLOAT,\n    "delivery" FLOAT,\n    "dementia" FLOAT,\n    "density" FLOAT,\n    "dental" FLOAT,\n    "dependence" FLOAT,\n    "depression" FLOAT,\n  ...

# %%
import snowflake.connector

USER = "<SNOWFLAKE_USER>"
PASSWORD = "<SNOWFLAKE_PASSWORD>"
ACCOUNT = "<SNOWFLAKE_ACCOUNT>"

# Connect to Snowflake
conn = snowflake.connector.connect(
    user=USER,
    password=PASSWORD,
    account=ACCOUNT,         
)

# Create a cursor object
cur = conn.cursor()

try:

    # Create a new warehouse
    cur.execute("CREATE WAREHOUSE IF NOT EXISTS clinical_trials_warehouse")

    # Create a new database
    cur.execute("CREATE DATABASE IF NOT EXISTS clinical_trials_db")

    # Use the newly created database and warehouse
    cur.execute("USE WAREHOUSE clinical_trials_warehouse")
    cur.execute("USE DATABASE clinical_trials_db")

    # Create a new schema
    cur.execute("CREATE SCHEMA IF NOT EXISTS clinical_trials_schema")

    # Use the newly created schema
    cur.execute("USE SCHEMA clinical_trials_schema")

    # Create a new table with the column definitions
    create_table_sql = f"""
    CREATE TABLE IF NOT EXISTS clinical_trial (
        {column_definitions_str}
    )
    """
    cur.execute(create_table_sql)

finally:
    # Close the cursos and the connection
    cur.close()
    conn.close()

# %%
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas

# Connect to Snowflake
conn = snowflake.connector.connect(
    user=USER,
    password=PASSWORD,
    account=ACCOUNT,
    warehouse='clinical_trials_warehouse',
    database='clinical_trials_db',
    schema='clinical_trials_schema'
)

# Create a cursor object
cur = conn.cursor()

try:

    # Set the schema
    cur.execute("USE SCHEMA clinical_trials_db.clinical_trials_schema")

    # Write data from the pandas DataFrame to the Snowflake table
    success, nchunks, nrows, _ = write_pandas(conn, df, 'CLINICAL_TRIAL')

    print(f"Successfully inserted {nrows} rows into the table.")

finally:
    # Close the cursor and the connection
    cur.close()
    conn.close()
# Out:
# C:\Users\m1000\AppData\Local\Temp\ipykernel_38288\1964639291.py:23: UserWarning: Pandas Dataframe has non-standard index of type <class 'pandas.core.indexes.base.Index'> which will not be written. Consider changing the index to pd.RangeIndex(start=0,...,step=1) or call reset_index() to keep index as column(s)
#   success, nchunks, nrows, _ = write_pandas(conn, df, 'CLINICAL_TRIAL')
# Successfully inserted 68999 rows into the table.
